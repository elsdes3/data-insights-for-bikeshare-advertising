# %% [markdown]
# # Get Data

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import json
import os
import sys
import warnings
from datetime import datetime
from glob import glob
from io import BytesIO
from zipfile import ZipFile

import duckdb
import geopandas as gpd
import holidays
import pandas as pd
import requests
from meteostat import Daily, Stations
from watermark import watermark

# %%
PROJ_ROOT = os.pardir
src_dir = os.path.join(PROJ_ROOT, "src")
sys.path.append(src_dir)

# %%
# %aimport clean
import clean as cl

# %aimport file_utils
import file_utils as flut

# %aimport geopandas_helpers
import geopandas_helpers as gpu

# %aimport open_data
import open_data as od

# %aimport pandas_utils
import pandas_utils as pu

# %%
def run_sql_query(query: str, verbose: bool=False) -> pd.DataFrame:
    """Run SQL query using DuckDB."""
    with warnings.catch_warnings():
        warnings.simplefilter("ignore", FutureWarning)
        df_query = duckdb.sql(query).df()
    if verbose:
        print(f"Query returned {len(df_query):,} rows")
    return df_query

# %% [markdown]
# ## About

# %% [markdown]
# Retrieve or generate the following datasets
#
# 1. Bike Share Toronto ridership from 2018 to 2023, inclusive
# 2. City of Toronto Census Tract Boundaries Geodata
# 3. City of Toronto Neighbourhood Boundaries Geodata
# 4. Bike Share Toronto station info
# 5. City of Toronto colleges and universities
# 6. City of Toronto Daily Weather Data
# 7. City of Toronto Downtown and East-West Adjacent Neighbourhoods (generated)
# 8. Bike Share Toronto Network Expandsion Plans (2023 to 2025, generated)
# 9. City of Toronto Public Transit (Train) Routes Geodata
# 10. List of public holidays in Canada for 2018 to 2023. inclusive

# %% [markdown]
# ## User Inputs

# %%
# weather
weather_start = datetime(2018, 1, 1)
weather_end = datetime(2023, 3, 31)
weather_station_near_coords = dict(lat=43.6771, lon=-79.6334)

# geodata
# # station info
url_spec = (
    'https://raw.githubusercontent.com/MobilityData/gbfs/master/systems.csv'
)
# # Toronto Open Data base URL
base_url = "https://ckan0.cf.opendata.inter.prod-toronto.ca"
# # Toronto Open Data geodata dataset parameters
neigh_boundary_params = {"id": "neighbourhoods"}
# # co-ordinate reference system and projection
crs = 4326
epsg = 4536
# # neighbourhoods located in or adjacent to downtown Toronto
neighs = [
    {"Neighbourhood": "University", "Location": "Downtown", 'is_downtown': True},
    {"Neighbourhood": "Kensington-Chinatown", "Location": "Downtown", 'is_downtown': True},
    {"Neighbourhood": "Wellington Place", "Location": "Downtown", 'is_downtown': True},
    {"Neighbourhood": "Harbourfront-CityPlace", "Location": "Downtown", 'is_downtown': True},
    {"Neighbourhood": "Bay-Cloverhill", "Location": "Downtown", 'is_downtown': True},
    {"Neighbourhood": "Yonge-Bay Corridor", "Location": "Downtown", 'is_downtown': True},
    {"Neighbourhood": "St Lawrence-East Bayfront-The Islands", "Location": "Downtown", 'is_downtown': True},
    {"Neighbourhood": "Church-Wellesley", "Location": "Downtown", 'is_downtown': True},
    {"Neighbourhood": "Downtown Yonge East", "Location": "Downtown", 'is_downtown': True},
    {"Neighbourhood": "North St.James Town", "Location": "Downtown", 'is_downtown': True},
    {"Neighbourhood": "Cabbagetown-South St.James Town", "Location": "Downtown", 'is_downtown': True},
    {"Neighbourhood": "Moss Park", "Location": "Downtown", 'is_downtown': True},
    {"Neighbourhood": "Regent Park", "Location": "Downtown", 'is_downtown': True},
    {"Neighbourhood": "Roncesvalles", "Location": "West of Downtown", 'is_downtown': False},
    {"Neighbourhood": "South Parkdale", "Location": "West of Downtown", 'is_downtown': False},
    {"Neighbourhood": "Dufferin Grove", "Location": "West of Downtown", 'is_downtown': False},
    {"Neighbourhood": "Little Portugal", "Location": "West of Downtown", 'is_downtown': False},
    {"Neighbourhood": "Palmerston-Little Italy", "Location": "West of Downtown", 'is_downtown': False},
    {"Neighbourhood": "Trinity-Bellwoods", "Location": "West of Downtown", 'is_downtown': False},
    {"Neighbourhood": "West Queen West", "Location": "West of Downtown", 'is_downtown': False},
    {"Neighbourhood": "Fort York-Liberty Village", "Location": "West of Downtown", 'is_downtown': False},
    {"Neighbourhood": "North Riverdale", "Location": "East of Downtown", 'is_downtown': False},
    {"Neighbourhood": "South Riverdale", "Location": "East of Downtown", 'is_downtown': False},
    {"Neighbourhood": "Blake-Jones", "Location": "East of Downtown", 'is_downtown': False},
]
# # college and university locations
coll_univ_locations = {
    "Centennial College (Progress Campus)": {"lat": 43.783936, "lon": -79.228288},
    "Centennial College (Morningside Campus)": {"lat": 43.786243, "lon": -79.193541},
    "George Brown College (St James Campus)": {"lat": 43.651708, "lon": -79.370745},
    "George Brown College (Casa Loma Campus)": {"lat": 43.676259, "lon": -79.410209},
    "George Brown College (Waterfront Campus)": {"lat": 43.644076, "lon": -79.365148},
    "Humber College (North Campus)": {"lat": 43.730310, "lon": -79.606184},
    "Humber College (Lakeshore Campus)": {"lat": 43.596058, "lon": -79.520169},
    "OCAD University": {"lat": 43.653133, "lon": -79.391391},
    "Seneca College (Markham Campus)": {"lat": 43.7955, "lon": -79.3496},
    "Seneca College (Newnham Campus)": {"lat": 43.7955, "lon": -79.3496},
    "Seneca College (York University Campus)": {"lat": 43.771106, "lon": -79.500216},
    "Seneca College (Yorkgate Campus)": {"lat": 43.758833, "lon": -79.518493},
    "University of Toronto": {"lat": 43.663985, "lon": -79.399905},
    "University of Toronto (Scarborough Campus)": {"lat": 43.783100, "lon": -79.187521},
    "Toronto Metropolitan University": {"lat": 43.657591, "lon": -79.378786},
    "York University": {"lat": 43.772831, "lon": -79.497522},
    "York University (Glendon Campus)": {"lat": 43.728159, "lon": -79.378038},
}
# # timezone
my_timezone = 'America/Toronto'
# # public transit train lines
base_url = "https://ckan0.cf.opendata.inter.prod-toronto.ca"
train_line_params = { "id": "ttc-subway-shapefiles"}
# # census tracts
fname_census_tracts = 'lct_000b21a_e.shp'

# %%
data_dir = os.path.join(PROJ_ROOT, 'data')
raw_data_dir = os.path.join(data_dir, 'raw', 'systems', 'toronto')

fpaths_bike_share_raw = glob(os.path.join(raw_data_dir, '*.csv'))
fpaths_weather = glob(
    os.path.join(raw_data_dir, 'daily_weather__*.parquet.gzip')
)
fpath_downtown_neighs = glob(
    os.path.join(raw_data_dir, 'downtown_neighbourhoods__*.parquet.gzip')
)
fpath_expansion = glob(
    os.path.join(raw_data_dir, 'network_expansion__*.parquet.gzip')
)
fpath_holidays = glob(
    os.path.join(raw_data_dir, 'fpath_holidays__*.parquet.gzip')
)
url = base_url + "/api/3/action/package_show"

# %% [markdown]
# ## Get Data

# %% [markdown]
# ### Bike Share Trips Data

# %% [markdown]
# Retrieve raw bike share trips (ridership) data from the Toronto Open Data Portal following the procedure below
#
# 1. Navigate to the [Toronto Open Data portal](https://www.toronto.ca/city-government/data-research-maps/open-data/)
# 2. Select **Open Data Portal**
# 3. Search for **bike share**
# 4. In the search results, select **Bike Share Toronto Ridership Data**
# 5. Select **DOWNLOAD DATA**
# 8. Click the **DOWNLOAD** button for each of the following **File**s
#    - *bikeshare-ridership-2018*
#    - *bikeshare-ridership-2019*
#    - *bikeshare-ridership-2020*
#    - *bikeshare-ridership-2021*
#    - *bikeshare-ridership-2022*
#    - *bikeshare-ridership-2023*

# %% [markdown]
# Verify that bike share ridership `.CSV` files were downloaded and exist locally in the correct filepath

# %%
assert len(fpaths_bike_share_raw) == 4+4+12+12+12+12

# %% [markdown]
# Extract path the latest `.csv` file with bike share ridership data

# %%
fpath_raw_trips = fpaths_bike_share_raw[-1]

# %% [markdown]
# Show all columns in the transit lines geodata

# %%
# %%time
pu.show_df(pd.read_csv(fpath_raw_trips, encoding='unicode_escape').convert_dtypes())
# Out:
# column   Trip Id Trip  Duration Start Station Id        Start Time  \
# dtype      Int64          Int64            Int64    string[python]
# nans       0              0                0                 0
# 0       25950721            487             7168  11/01/2023 00:00
# 1       25950722            199             7335  11/01/2023 00:00
# 2       25950723            912             7263  11/01/2023 00:00
# 3       25950724            393             7155  11/01/2023 00:00
# 4       25950725            294             7033  11/01/2023 00:00
# ...          ...            ...              ...               ...
# 393868  26395694            405             7660  11/30/2023 23:59
# 393869  26395695          10103             7311  11/30/2023 23:59
# 393870  26395696            248             7007  11/30/2023 23:59
# 393871  26395698             65             7285  11/30/2023 23:59
# 393872  26395699            254             7333  11/30/2023 23:59
#
# column                Start Station Name End Station Id          End Time  \
# dtype                     string[python]          Int64    string[python]
# nans                               47861          233               0
# 0                 Queens Quay / Yonge St           7064  11/01/2023 00:08
# 1        Bay St / Bloor St W (West Side)           7001  11/01/2023 00:03
# 2       Walton St / Elizabeth St - SMART           7176  11/01/2023 00:15
# 3                Bathurst St / Lennox St           7531  11/01/2023 00:06
# 4                          Union Station           7059  11/01/2023 00:05
# ...                                  ...            ...               ...
# 393868                   285 Victoria St           7065  12/01/2023 00:05
# 393869       Sherbourne St / Isabella St           7311  12/01/2023 02:47
# 393870             College St / Huron St           7274  12/01/2023 00:03
# 393871  Spadina Ave / Harbord St - SMART           7170  12/01/2023 00:00
# 393872           King St E / Victoria St           7505  12/01/2023 00:04
#
# column                            End Station Name Bike Id      User Type
# dtype                               string[python]   Int64 string[python]
# nans                                         48003   0              0
# 0                                 51 Parliament St    6069  Casual Member
# 1                        Wellesley Station Green P    4350  Casual Member
# 2                     Bathurst St / Fort York Blvd     253  Casual Member
# 3                             541 Huron St - SMART    7117  Casual Member
# 4                       Front St W / Blue Jays Way     610  Casual Member
# ...                                            ...     ...            ...
# 393868                 Dundas St E / Parliament St     582  Casual Member
# 393869                 Sherbourne St / Isabella St    4358  Casual Member
# 393870  Queen's Park Cres E / Grosvenor St - SMART    2638  Casual Member
# 393871                  Spadina Ave / Willcocks St    5184  Casual Member
# 393872           Ontario St / Adelaide St E -SMART    2306  Casual Member
#
# [393873 rows x 10 columns]
# CPU times: user 722 ms, sys: 63.3 ms, total: 786 ms
# Wall time: 847 ms

# %% [markdown]
# ### Toronto Census Tract Boundaries

# %% [markdown]
# Retrieve Census Tracts data from Statistics Canada (StatCan) following the procedure below
#
# 1. Navigate to the [StatCan page for Forward Sortation Area downloads](https://www150.statcan.gc.ca/n1/en/catalogue/92-179-X)
# 2. Select Title > Census Forward Sortation Area Boundary File, Census year 2021
# 3. Select Type > Cartographic Boundary Files (CBF)
# 4. In Administrative Boundaries, make no selection
# 5. Select Statistical Boundaries > Census tracts
# 6. In Non-standard boundaries, make no selection
# 7. Select Format > Downloadable > `Shapefile (.shp)`
# 8. Click Continue
# 9. Click the link to the ZIP document - *lcd_000b21a_e.zip (ZIP version, 136,594.0 kb)*
# 10. Extract the file into `data/raw/lct_000b21a_e`. The filepath of the `.shp` file should be `data/raw/lct_000b21a_e/lct_000b21a_e.shp`.

# %%
shp_filepath_census = os.path.join(
    raw_data_dir, os.path.splitext(fname_census_tracts)[0], fname_census_tracts
)

# %% [markdown]
# Verify that census tracts `.shp` file was downloaded and exists locally in the correct filepath

# %%
assert os.path.exists(shp_filepath_census)

# %% [markdown]
# Show all columns in the census tract boundaries geodata

# %%
# %%time
pu.show_df(gpd.read_file(shp_filepath_census).convert_dtypes())
# Out:
# ERROR 1: PROJ: proj_create_from_database: Open of /opt/conda/envs/get-data/share/proj failed
# column          CTUID                DGUID         CTNAME  LANDAREA  \
# dtype  string[python]       string[python] string[python]   Float64
# nans                0                    0              0         0
# 0          5370001.08  2021S05075370001.08        0001.08    1.6383
# 1          0010002.00  2021S05070010002.00        0002.00    1.9638
# 2          5370001.09  2021S05075370001.09        0001.09    1.9699
# 3          5370120.02  2021S05075370120.02        0120.02    76.965
# 4          0010006.00  2021S05070010006.00        0006.00    1.0467
# ...               ...                  ...            ...       ...
# 6242       5591003.00  2021S05075591003.00        1003.00  227.6981
# 6243       5591004.00  2021S05075591004.00        1004.00   18.3792
# 6244       5800300.00  2021S05075800300.00        0300.00  314.4614
# 6245       6020800.00  2021S05076020800.00        0800.00    8.6987
# 6246       7050106.00  2021S05077050106.00        0106.00    1.2213
#
# column          PRUID                                           geometry
# dtype  string[python]                                           geometry
# nans                0                                                  0
# 0                  35  POLYGON ((7196507.366 869787.991, 7196501.617 ...
# 1                  10  POLYGON ((8980216.643 2151065.360, 8980377.609...
# 2                  35  POLYGON ((7196437.003 869160.246, 7196434.403 ...
# 3                  35  POLYGON ((7189475.703 865662.849, 7189448.943 ...
# 4                  10  POLYGON ((8980091.143 2152478.609, 8980100.254...
# ...               ...                                                ...
# 6242               35  POLYGON ((6984736.931 712991.680, 6984866.560 ...
# 6243               35  POLYGON ((6981553.974 701146.583, 6981728.169 ...
# 6244               35  POLYGON ((7084392.943 1223795.154, 7084451.317...
# 6245               46  POLYGON ((5828241.160 1509841.949, 5828231.780...
# 6246               47  POLYGON ((5298374.186 1710708.500, 5298364.069...
#
# [6247 rows x 6 columns]
# CPU times: user 2.05 s, sys: 116 ms, total: 2.16 s
# Wall time: 2.16 s

# %% [markdown]
# ### Toronto Neighbourhood Boundaries

# %% [markdown]
# Retrieve link to [neighbourhood boundaries geodata](https://open.toronto.ca/dataset/neighbourhoods/)

# %%
# %%time
shp_filepath = od.download_geo_open_data(
    raw_data_dir, base_url, neigh_boundary_params
)
# Out:
# Retrieved dataset neighbourhoods from filepath https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/neighbourhoods/resource/1d38e8b7-65a8-4dd0-88b0-ad2ce938126e/download/neighbourhoods-4326.geojson
# CPU times: user 13.7 ms, sys: 4.54 ms, total: 18.2 ms
# Wall time: 181 ms

# %% [markdown]
# Verify that retrieved boundaries link is valid

# %%
# %%time
r = requests.get(shp_filepath)
assert r.status_code == 200
# Out:
# CPU times: user 20.9 ms, sys: 8.32 ms, total: 29.3 ms
# Wall time: 383 ms

# %% [markdown]
# Show all columns in the Neighbourhoods boundaries geodata

# %%
# %%time
pu.show_df(gpd.read_file(shp_filepath).convert_dtypes())
# Out:
# column   _id  AREA_ID AREA_ATTR_ID PARENT_AREA_ID AREA_SHORT_CODE  \
# dtype  Int64    Int64        Int64          Int64  string[python]
# nans       0        0            0              0               0
# 0          1  2502366     26022881              0             174
# 1          2  2502365     26022880              0             173
# 2          3  2502364     26022879              0             172
# 3          4  2502363     26022878              0             171
# 4          5  2502362     26022877              0             170
# ..       ...      ...          ...            ...             ...
# 153      154  2502213     26022728              0             001
# 154      155  2502212     26022727              0             024
# 155      156  2502211     26022726              0             023
# 156      157  2502210     26022725              0             022
# 157      158  2502209     26022724              0             021
#
# column AREA_LONG_CODE                  AREA_NAME  \
# dtype  string[python]             string[python]
# nans                0                          0
# 0                 174  South Eglinton-Davisville
# 1                 173              North Toronto
# 2                 172         Dovercourt Village
# 3                 171   Junction-Wallace Emerson
# 4                 170         Yonge-Bay Corridor
# ..                ...                        ...
# 153               001     West Humber-Clairville
# 154               024                Black Creek
# 155               023       Pelmo Park-Humberlea
# 156               022                 Humbermede
# 157               021              Humber Summit
#
# column                        AREA_DESC                        CLASSIFICATION  \
# dtype                    string[python]                        string[python]
# nans                                  0                                     0
# 0       South Eglinton-Davisville (174)  Not an NIA or Emerging Neighbourhood
# 1                   North Toronto (173)  Not an NIA or Emerging Neighbourhood
# 2              Dovercourt Village (172)  Not an NIA or Emerging Neighbourhood
# 3        Junction-Wallace Emerson (171)  Not an NIA or Emerging Neighbourhood
# 4              Yonge-Bay Corridor (170)  Not an NIA or Emerging Neighbourhood
# ..                                  ...                                   ...
# 153          West Humber-Clairville (1)  Not an NIA or Emerging Neighbourhood
# 154                    Black Creek (24)        Neighbourhood Improvement Area
# 155           Pelmo Park-Humberlea (23)  Not an NIA or Emerging Neighbourhood
# 156                     Humbermede (22)        Neighbourhood Improvement Area
# 157                  Humber Summit (21)        Neighbourhood Improvement Area
#
# column CLASSIFICATION_CODE  OBJECTID  \
# dtype       string[python]     Int64
# nans                     0         0
# 0                       NA  17824737
# 1                       NA  17824753
# 2                       NA  17824769
# 3                       NA  17824785
# 4                       NA  17824801
# ..                     ...       ...
# 153                     NA  17827185
# 154                    NIA  17827201
# 155                     NA  17827217
# 156                    NIA  17827233
# 157                    NIA  17827249
#
# column                                           geometry
# dtype                                            geometry
# nans                                                    0
# 0       MULTIPOLYGON (((-79.38635 43.69783, -79.38623 ...
# 1       MULTIPOLYGON (((-79.39744 43.70693, -79.39837 ...
# 2       MULTIPOLYGON (((-79.43411 43.66015, -79.43537 ...
# 3       MULTIPOLYGON (((-79.43870 43.66766, -79.43841 ...
# 4       MULTIPOLYGON (((-79.38404 43.64497, -79.38502 ...
# ..                                                    ...
# 153     MULTIPOLYGON (((-79.59037 43.73401, -79.58942 ...
# 154     MULTIPOLYGON (((-79.51915 43.77399, -79.51901 ...
# 155     MULTIPOLYGON (((-79.53225 43.73505, -79.52938 ...
# 156     MULTIPOLYGON (((-79.52813 43.74425, -79.52721 ...
# 157     MULTIPOLYGON (((-79.53396 43.76886, -79.53227 ...
#
# [158 rows x 12 columns]
# CPU times: user 181 ms, sys: 123 µs, total: 182 ms
# Wall time: 366 ms

# %% [markdown]
# ### Bike Share Station Info

# %% [markdown]
# #### Extract

# %% [markdown]
# Get info for for currently active stations by querying the [GBFS](https://gbfs.org/#) [`/station_information`](https://github.com/MobilityData/gbfs/blob/v2.0/gbfs.md#station_informationjson) [endpoint](https://github.com/MobilityData/gbfs/blob/v2.0/gbfs.md#version-endpoints) from the [API for the Bike Share Toronto network](https://tor.publicbikesystem.net/customer/gbfs/v2/gbfs.json)

# %%
# %%time
# get network info URL from feeds file
query = f"""
        WITH t1 AS (
            SELECT column0 AS country_code,
                   column1 AS name,
                   column2 AS location,
                   column3 AS system_id,
                   column4 AS url,
                   column5 AS auto_discovery_url,
                   column6 AS authentication_info
            FROM '{url_spec}'
            WHERE country_code <> 'Country Code'
            AND location LIKE '%Toronto%'
        )
        SELECT auto_discovery_url
        FROM t1
        """
url_feed = run_sql_query(query).squeeze()

# query network info URL to get station info URL
url_info = [
    f
    for f in json.loads(requests.get(url_feed).content)['data']['en']['feeds']
    if f['name'] == 'station_information'
][0]['url']

# query station info (API) URL
df_info_raw = (
    pd.DataFrame.from_records(
        json.loads(requests.get(url_info).content)['data']['stations']
    )
)
with pd.option_context('display.max_columns', None):
    pu.show_df(df_info_raw)
# Out:
# column station_id                                    name  \
# dtype      object                                  object
# nans          0                                       0
# 0            7000            Fort York  Blvd / Capreol Ct
# 1            7001               Wellesley Station Green P
# 2            7002              St. George St / Bloor St W
# 3            7003                Madison Ave / Bloor St W
# 4            7005                     King St W / York St
# ..            ...                                     ...
# 788          7926             McRae Dr / Laird Dr - SMART
# 789          7927  Strachan Ave / East Liberty St - SMART
# 790          7928                   Simcoe St / Pullan Pl
# 791          7929         Spadina Ave / Bulwer St- SMART
# 792          7930                   Dunn Ave / Queen St W
#
# column physical_configuration        lat        lon altitude  \
# dtype                  object    float64    float64  float64
# nans                      0          0          0        8
# 0                     REGULAR  43.639832 -79.395954      0.0
# 1         ELECTRICBIKESTATION  43.664964 -79.383550      0.0
# 2                     REGULAR  43.667333 -79.399429      0.0
# 3                     REGULAR  43.667158 -79.402761      NaN
# 4                     REGULAR  43.648001 -79.383177      0.0
# ..                        ...        ...        ...      ...
# 788             SMARTMAPFRAME  43.709793 -79.363892      0.0
# 789             SMARTMAPFRAME  43.639065 -79.410810      0.0
# 790                   REGULAR  43.651053 -79.387649      0.0
# 791             SMARTMAPFRAME  43.649354 -79.396757      0.0
# 792                   REGULAR  43.639523 -79.433960      0.0
#
# column                          address capacity is_charging_station  \
# dtype                            object    int64                bool
# nans                                1        0                   0
# 0          Fort York  Blvd / Capreol Ct       35               False
# 1                     Yonge / Wellesley       23                True
# 2            St. George St / Bloor St W       19               False
# 3              Madison Ave / Bloor St W       15               False
# 4                   King St W / York St       23               False
# ..                                  ...      ...                 ...
# 788                 McRae Dr / Laird Dr       24               False
# 789      Strachan Ave / East Liberty St       24               False
# 790               Simcoe St / Pullan Pl       31               False
# 791     Spadina Ave / Bulwer St- SMART        12               False
# 792                        240 Dunn Ave       15               False
#
# column geofenced_capacity                         rental_methods  \
# dtype               int64                                 object
# nans                  0                                      0
# 0                       0  [KEY, TRANSITCARD, CREDITCARD, PHONE]
# 1                       0  [KEY, TRANSITCARD, CREDITCARD, PHONE]
# 2                       0  [KEY, TRANSITCARD, CREDITCARD, PHONE]
# 3                       0  [KEY, TRANSITCARD, CREDITCARD, PHONE]
# 4                       0  [KEY, TRANSITCARD, CREDITCARD, PHONE]
# ..                    ...                                    ...
# 788                     0              [KEY, TRANSITCARD, PHONE]
# 789                     0              [KEY, TRANSITCARD, PHONE]
# 790                     0  [KEY, TRANSITCARD, CREDITCARD, PHONE]
# 791                     0              [KEY, TRANSITCARD, PHONE]
# 792                     0  [KEY, TRANSITCARD, CREDITCARD, PHONE]
#
# column is_virtual_station groups                          obcn  \
# dtype                bool object                        object
# nans                  0      0                             0
# 0                   False     []                  647-643-9607
# 1                   False     []                  416-617-9576
# 2                   False     []                  647-643-9615
# 3                   False     []                  647-631-4587
# 4                   False     []                  647-643-9693
# ..                    ...    ...                           ...
# 788                 False     []      Ward - 15( 180 Laird Dr)
# 789                 False     []  Ward-10 (39 East Liberty )st
# 790                 False     []      Ward- 10( 180 Simcoe St)
# 791                 False     []   Ward 10 -( 174 Spadina Ave)
# 792                 False     []       Ward 4 - (240 Dunn Ave)
#
# column nearby_distance _bluetooth_id _ride_code_support rental_uris post_code  \
# dtype          float64        object               bool      object    object
# nans               0             0                  0           0         292
# 0                500.0                             True          {}       NaN
# 1                500.0                             True          {}   M4Y 1G7
# 2                500.0                             True          {}       NaN
# 3                500.0                             True          {}       NaN
# 4                500.0                             True          {}       NaN
# ..                 ...           ...                ...         ...       ...
# 788              300.0                             True          {}   M4G 3V7
# 789              100.0                             True          {}   M6K 0A7
# 790              100.0                             True          {}   M5T 2W5
# 791              100.0                             True          {}   M5T 2C2
# 792              300.0                             True          {}   M6K 3K6
#
# column is_valet_station cross_street
# dtype            object       object
# nans                776          631
# 0                   NaN          NaN
# 1                   NaN          NaN
# 2                   NaN          NaN
# 3                   NaN          NaN
# 4                   NaN          NaN
# ..                  ...          ...
# 788                 NaN          NaN
# 789                 NaN          NaN
# 790                 NaN          NaN
# 791                 NaN          NaN
# 792                 NaN            -
#
# [793 rows x 21 columns]
# CPU times: user 654 ms, sys: 128 ms, total: 782 ms
# Wall time: 1.63 s

# %% [markdown]
# #### Transform

# %% [markdown]
# In order to save data with columns of a `struct` or `object` datatype, apply JSON encoding to all values in these columns in order to handle values with an empty `object` (eg. empty Python `list`)

# %%
# %%time
df_info_raw = (
    df_info_raw
    .assign(
        rental_methods=lambda df: df['rental_methods'].apply(json.dumps),
        is_virtual_station=lambda df: df['is_virtual_station'].apply(json.dumps),
        rental_uris=lambda df: df['rental_uris'].apply(json.dumps),
        groups=lambda df: df['groups'].apply(json.dumps),
    )
    .convert_dtypes()
)
with pd.option_context('display.max_columns', None):
    pu.show_df(df_info_raw)
# Out:
# column     station_id                                    name  \
# dtype  string[python]                          string[python]
# nans              0                                       0
# 0                7000            Fort York  Blvd / Capreol Ct
# 1                7001               Wellesley Station Green P
# 2                7002              St. George St / Bloor St W
# 3                7003                Madison Ave / Bloor St W
# 4                7005                     King St W / York St
# ..                ...                                     ...
# 788              7926             McRae Dr / Laird Dr - SMART
# 789              7927  Strachan Ave / East Liberty St - SMART
# 790              7928                   Simcoe St / Pullan Pl
# 791              7929         Spadina Ave / Bulwer St- SMART
# 792              7930                   Dunn Ave / Queen St W
#
# column physical_configuration        lat        lon altitude  \
# dtype          string[python]    Float64    Float64  Float64
# nans                      0          0          0        8
# 0                     REGULAR  43.639832 -79.395954      0.0
# 1         ELECTRICBIKESTATION  43.664964  -79.38355      0.0
# 2                     REGULAR  43.667333 -79.399429      0.0
# 3                     REGULAR  43.667158 -79.402761     <NA>
# 4                     REGULAR  43.648001 -79.383177      0.0
# ..                        ...        ...        ...      ...
# 788             SMARTMAPFRAME  43.709793 -79.363892      0.0
# 789             SMARTMAPFRAME  43.639065  -79.41081      0.0
# 790                   REGULAR  43.651053 -79.387649      0.0
# 791             SMARTMAPFRAME  43.649354 -79.396757      0.0
# 792                   REGULAR  43.639523  -79.43396      0.0
#
# column                          address capacity is_charging_station  \
# dtype                    string[python]    Int64             boolean
# nans                                1        0                   0
# 0          Fort York  Blvd / Capreol Ct       35               False
# 1                     Yonge / Wellesley       23                True
# 2            St. George St / Bloor St W       19               False
# 3              Madison Ave / Bloor St W       15               False
# 4                   King St W / York St       23               False
# ..                                  ...      ...                 ...
# 788                 McRae Dr / Laird Dr       24               False
# 789      Strachan Ave / East Liberty St       24               False
# 790               Simcoe St / Pullan Pl       31               False
# 791     Spadina Ave / Bulwer St- SMART        12               False
# 792                        240 Dunn Ave       15               False
#
# column geofenced_capacity                                 rental_methods  \
# dtype               Int64                                 string[python]
# nans                  0                                              0
# 0                       0  ["KEY", "TRANSITCARD", "CREDITCARD", "PHONE"]
# 1                       0  ["KEY", "TRANSITCARD", "CREDITCARD", "PHONE"]
# 2                       0  ["KEY", "TRANSITCARD", "CREDITCARD", "PHONE"]
# 3                       0  ["KEY", "TRANSITCARD", "CREDITCARD", "PHONE"]
# 4                       0  ["KEY", "TRANSITCARD", "CREDITCARD", "PHONE"]
# ..                    ...                                            ...
# 788                     0                ["KEY", "TRANSITCARD", "PHONE"]
# 789                     0                ["KEY", "TRANSITCARD", "PHONE"]
# 790                     0  ["KEY", "TRANSITCARD", "CREDITCARD", "PHONE"]
# 791                     0                ["KEY", "TRANSITCARD", "PHONE"]
# 792                     0  ["KEY", "TRANSITCARD", "CREDITCARD", "PHONE"]
#
# column is_virtual_station         groups                          obcn  \
# dtype      string[python] string[python]                string[python]
# nans                  0              0                             0
# 0                   false             []                  647-643-9607
# 1                   false             []                  416-617-9576
# 2                   false             []                  647-643-9615
# 3                   false             []                  647-631-4587
# 4                   false             []                  647-643-9693
# ..                    ...            ...                           ...
# 788                 false             []      Ward - 15( 180 Laird Dr)
# 789                 false             []  Ward-10 (39 East Liberty )st
# 790                 false             []      Ward- 10( 180 Simcoe St)
# 791                 false             []   Ward 10 -( 174 Spadina Ave)
# 792                 false             []       Ward 4 - (240 Dunn Ave)
#
# column nearby_distance  _bluetooth_id _ride_code_support    rental_uris  \
# dtype          Float64 string[python]            boolean string[python]
# nans               0              0                  0              0
# 0                500.0                              True             {}
# 1                500.0                              True             {}
# 2                500.0                              True             {}
# 3                500.0                              True             {}
# 4                500.0                              True             {}
# ..                 ...            ...                ...            ...
# 788              300.0                              True             {}
# 789              100.0                              True             {}
# 790              100.0                              True             {}
# 791              100.0                              True             {}
# 792              300.0                              True             {}
#
# column      post_code is_valet_station   cross_street
# dtype  string[python]          boolean string[python]
# nans              292              776            631
# 0                <NA>             <NA>           <NA>
# 1             M4Y 1G7             <NA>           <NA>
# 2                <NA>             <NA>           <NA>
# 3                <NA>             <NA>           <NA>
# 4                <NA>             <NA>           <NA>
# ..                ...              ...            ...
# 788           M4G 3V7             <NA>           <NA>
# 789           M6K 0A7             <NA>           <NA>
# 790           M5T 2W5             <NA>           <NA>
# 791           M5T 2C2             <NA>           <NA>
# 792           M6K 3K6             <NA>              -
#
# [793 rows x 21 columns]
# CPU times: user 24.8 ms, sys: 287 µs, total: 25.1 ms
# Wall time: 24.6 ms

# %% [markdown]
# Use the boundaries geodata retrieved above to append the neighbourhood and census tract to each bike share station

# %%
# %%time
df_info = (
    gpu.get_data_with_neighbourhood(
        # load neighbourhoods for city
        gpd.read_file(shp_filepath),
        (
            gpu.get_data_with_neighbourhood(
                # load census tracts for city
                (
                    gpd.read_file(shp_filepath_census)
                    .query(
                        "(PRUID == '35') & "
                        "(CTUID.str.startswith('535')) & "
                        "(CTNAME.str.startswith('01') | "
                        "CTNAME.str.startswith('02') | "
                        "CTNAME.str.startswith('03') | "
                        "CTNAME.str.startswith('00'))"
                    )
                    .reset_index(drop=True)
                    .to_crs(crs)
                    .drop(columns=['DGUID', 'CTNAME', 'LANDAREA', 'PRUID'])
                    .convert_dtypes()
                ),
                df_info_raw.assign(row_id=lambda df: range(len(df))),
                "lat",
                "lon",
                "row_id",
                ['row_id', "CTUID", "geometry"],
                'CTUID',
                crs,
            )
            .drop(columns=['row_id'])
            .assign(row_id=lambda df: range(len(df)))
        ),
        "lat",
        "lon",
        "row_id",
        ['row_id', "AREA_NAME", "geometry"],
        'AREA_NAME',
        crs,
    )
    .rename(columns={"CTUID": "census_tract_id", "AREA_NAME": "Neighbourhood"})
    .sort_values(by=["station_id"], ignore_index=True)
    .astype({"census_tract_id": pd.StringDtype(), "Neighbourhood": pd.StringDtype()})
    .drop(columns=['row_id'])
    .convert_dtypes()
)
with pd.option_context('display.max_columns', None):
    pu.show_df(df_info)
# Out:
# Extracted neighbourhood name.
# Dropped 0 rows with a missing CTUID (geodata) column
# Added geodata to data.
# Extracted neighbourhood name.
# Dropped 0 rows with a missing AREA_NAME (geodata) column
# Added geodata to data.
# column     station_id                                    name  \
# dtype  string[python]                          string[python]
# nans              0                                       0
# 0                7000            Fort York  Blvd / Capreol Ct
# 1                7001               Wellesley Station Green P
# 2                7002              St. George St / Bloor St W
# 3                7003                Madison Ave / Bloor St W
# 4                7005                     King St W / York St
# ..                ...                                     ...
# 785              7926             McRae Dr / Laird Dr - SMART
# 786              7927  Strachan Ave / East Liberty St - SMART
# 787              7928                   Simcoe St / Pullan Pl
# 788              7929         Spadina Ave / Bulwer St- SMART
# 789              7930                   Dunn Ave / Queen St W
#
# column physical_configuration        lat        lon altitude  \
# dtype          string[python]    Float64    Float64  Float64
# nans                      0          0          0        8
# 0                     REGULAR  43.639832 -79.395954      0.0
# 1         ELECTRICBIKESTATION  43.664964  -79.38355      0.0
# 2                     REGULAR  43.667333 -79.399429      0.0
# 3                     REGULAR  43.667158 -79.402761     <NA>
# 4                     REGULAR  43.648001 -79.383177      0.0
# ..                        ...        ...        ...      ...
# 785             SMARTMAPFRAME  43.709793 -79.363892      0.0
# 786             SMARTMAPFRAME  43.639065  -79.41081      0.0
# 787                   REGULAR  43.651053 -79.387649      0.0
# 788             SMARTMAPFRAME  43.649354 -79.396757      0.0
# 789                   REGULAR  43.639523  -79.43396      0.0
#
# column                          address capacity is_charging_station  \
# dtype                    string[python]    Int64             boolean
# nans                                1        0                   0
# 0          Fort York  Blvd / Capreol Ct       35               False
# 1                     Yonge / Wellesley       23                True
# 2            St. George St / Bloor St W       19               False
# 3              Madison Ave / Bloor St W       15               False
# 4                   King St W / York St       23               False
# ..                                  ...      ...                 ...
# 785                 McRae Dr / Laird Dr       24               False
# 786      Strachan Ave / East Liberty St       24               False
# 787               Simcoe St / Pullan Pl       31               False
# 788     Spadina Ave / Bulwer St- SMART        12               False
# 789                        240 Dunn Ave       15               False
#
# column geofenced_capacity                                 rental_methods  \
# dtype               Int64                                 string[python]
# nans                  0                                              0
# 0                       0  ["KEY", "TRANSITCARD", "CREDITCARD", "PHONE"]
# 1                       0  ["KEY", "TRANSITCARD", "CREDITCARD", "PHONE"]
# 2                       0  ["KEY", "TRANSITCARD", "CREDITCARD", "PHONE"]
# 3                       0  ["KEY", "TRANSITCARD", "CREDITCARD", "PHONE"]
# 4                       0  ["KEY", "TRANSITCARD", "CREDITCARD", "PHONE"]
# ..                    ...                                            ...
# 785                     0                ["KEY", "TRANSITCARD", "PHONE"]
# 786                     0                ["KEY", "TRANSITCARD", "PHONE"]
# 787                     0  ["KEY", "TRANSITCARD", "CREDITCARD", "PHONE"]
# 788                     0                ["KEY", "TRANSITCARD", "PHONE"]
# 789                     0  ["KEY", "TRANSITCARD", "CREDITCARD", "PHONE"]
#
# column is_virtual_station         groups                          obcn  \
# dtype      string[python] string[python]                string[python]
# nans                  0              0                             0
# 0                   false             []                  647-643-9607
# 1                   false             []                  416-617-9576
# 2                   false             []                  647-643-9615
# 3                   false             []                  647-631-4587
# 4                   false             []                  647-643-9693
# ..                    ...            ...                           ...
# 785                 false             []      Ward - 15( 180 Laird Dr)
# 786                 false             []  Ward-10 (39 East Liberty )st
# 787                 false             []      Ward- 10( 180 Simcoe St)
# 788                 false             []   Ward 10 -( 174 Spadina Ave)
# 789                 false             []       Ward 4 - (240 Dunn Ave)
#
# column nearby_distance  _bluetooth_id _ride_code_support    rental_uris  \
# dtype          Float64 string[python]            boolean string[python]
# nans               0              0                  0              0
# 0                500.0                              True             {}
# 1                500.0                              True             {}
# 2                500.0                              True             {}
# 3                500.0                              True             {}
# 4                500.0                              True             {}
# ..                 ...            ...                ...            ...
# 785              300.0                              True             {}
# 786              100.0                              True             {}
# 787              100.0                              True             {}
# 788              100.0                              True             {}
# 789              300.0                              True             {}
#
# column      post_code is_valet_station   cross_street census_tract_id  \
# dtype  string[python]          boolean string[python]  string[python]
# nans              292              773            628             0
# 0                <NA>             <NA>           <NA>      5350012.01
# 1             M4Y 1G7             <NA>           <NA>      5350063.06
# 2                <NA>             <NA>           <NA>      5350061.00
# 3                <NA>             <NA>           <NA>      5350091.01
# 4                <NA>             <NA>           <NA>      5350014.00
# ..                ...              ...            ...             ...
# 785           M4G 3V7             <NA>           <NA>      5350195.02
# 786           M6K 0A7             <NA>           <NA>      5350008.01
# 787           M5T 2W5             <NA>           <NA>      5350036.00
# 788           M5T 2C2             <NA>           <NA>      5350039.00
# 789           M6K 3K6             <NA>              -      5350005.00
#
# column              Neighbourhood
# dtype              string[python]
# nans                          0
# 0          Harbourfront-CityPlace
# 1                Church-Wellesley
# 2                      University
# 3                           Annex
# 4              Yonge-Bay Corridor
# ..                            ...
# 785            Leaside-Bennington
# 786     Fort York-Liberty Village
# 787          Kensington-Chinatown
# 788          Kensington-Chinatown
# 789                South Parkdale
#
# [790 rows x 23 columns]
# CPU times: user 2.38 s, sys: 11.5 ms, total: 2.39 s
# Wall time: 2.46 s

# %% [markdown]
# #### Load

# %% [markdown]
# Export station info to disk

# %%
fname_prefix = "stations_info_raw"
_ = df_info_raw.pipe(flut.load, raw_data_dir, fname_prefix, my_timezone, True)
# Out:
# Exported 793 rows of stations_info_raw data to /home/jovyan/data/raw/systems/toronto/stations_info_raw__20240310_172839.parquet.gzip

# %% [markdown]
# Export station info with neighbourhood and census tract to disk

# %%
fname_prefix = "stations_info"
_ = df_info.pipe(flut.load, raw_data_dir, fname_prefix, my_timezone, True)
# Out:
# Exported 790 rows of stations_info data to /home/jovyan/data/raw/systems/toronto/stations_info__20240310_172839.parquet.gzip

# %% [markdown]
# ### Colleges and Universities

# %% [markdown]
# #### Extract

# %%
df_colleges_univs = (
    pd.DataFrame.from_dict(coll_univ_locations, orient="index")
    .reset_index()
    .reset_index()
    .rename(
        columns={
            "level_0": "cu_id",
            "index": "cu_name",
        }
    )
)

# %% [markdown]
# **Notes**
#
# 1. The campus locations are listed below
#    - [Centennial College](https://www.centennialcollege.ca/locations)
#    - [George Brown College](https://www.georgebrown.ca/about/campuses-locations)
#    - [Humber College](https://humber.ca/about-humber/campuses-facilities/)
#    - [Toronto Metropolitan University](https://www.torontomu.ca/maps/)
#    - [Seneca College](https://www.senecapolytechnic.ca/campuses.html)
#    - [University of Toronto](https://www.utoronto.ca/university-life/campuses)
#    - [York University](https://www.yorku.ca/campuses/)
# 2. Only campuses within the city of Toronto are used here.

# %% [markdown]
# #### Transform

# %% [markdown]
# Use the boundaries geodata retrieved above to append the neighbourhood and census tract to each college and university location

# %%
# %%time
df_colleges_univs = (
    gpu.get_data_with_neighbourhood(
        # load neighbourhoods for city
        gpd.read_file(shp_filepath),
        (
            gpu.get_data_with_neighbourhood(
                # load census tracts for city
                (
                    gpd.read_file(shp_filepath_census)
                    .query(
                        "(PRUID == '35') & "
                        "(CTUID.str.startswith('535')) & "
                        "(CTNAME.str.startswith('01') | "
                        "CTNAME.str.startswith('02') | "
                        "CTNAME.str.startswith('03') | "
                        "CTNAME.str.startswith('00'))"
                    )
                    .reset_index(drop=True)
                    .to_crs(crs)
                    .drop(columns=['DGUID', 'CTNAME', 'LANDAREA', 'PRUID'])
                    .convert_dtypes()
                ),
                df_colleges_univs,
                "lat",
                "lon",
                "cu_id",
                ['cu_id', "CTUID", "geometry"],
                'CTUID',
                crs,
            )
        ),
        "lat",
        "lon",
        "cu_id",
        ['cu_id', "AREA_NAME", "geometry"],
        'AREA_NAME',
        crs,
    )
    .rename(columns={"CTUID": "census_tract_id", "AREA_NAME": "Neighbourhood"})
    .sort_values(by=["cu_id"], ignore_index=True)
    .astype({"census_tract_id": pd.StringDtype(), "Neighbourhood": pd.StringDtype()})
    .convert_dtypes()
)
with pd.option_context('display.max_columns', None):
    pu.show_df(df_colleges_univs)
# Out:
# Extracted neighbourhood name.
# Dropped 0 rows with a missing CTUID (geodata) column
# Added geodata to data.
# Extracted neighbourhood name.
# Dropped 0 rows with a missing AREA_NAME (geodata) column
# Added geodata to data.
# column cu_id                                     cu_name        lat  \
# dtype  Int64                              string[python]    Float64
# nans       0                                           0          0
# 0          0        Centennial College (Progress Campus)  43.783936
# 1          1     Centennial College (Morningside Campus)  43.786243
# 2          2      George Brown College (St James Campus)  43.651708
# 3          3     George Brown College (Casa Loma Campus)  43.676259
# 4          4    George Brown College (Waterfront Campus)  43.644076
# 5          5               Humber College (North Campus)   43.73031
# 6          6           Humber College (Lakeshore Campus)  43.596058
# 7          7                             OCAD University  43.653133
# 8          8             Seneca College (Markham Campus)    43.7955
# 9          9             Seneca College (Newnham Campus)    43.7955
# 10        10     Seneca College (York University Campus)  43.771106
# 11        11            Seneca College (Yorkgate Campus)  43.758833
# 12        12                       University of Toronto  43.663985
# 13        13  University of Toronto (Scarborough Campus)    43.7831
# 14        14             Toronto Metropolitan University  43.657591
# 15        15                             York University  43.772831
# 16        16            York University (Glendon Campus)  43.728159
#
# column        lon census_tract_id                          Neighbourhood
# dtype     Float64  string[python]                         string[python]
# nans            0               0                                      0
# 0      -79.228288      5350363.07                           Woburn North
# 1      -79.193541      5350362.03                         Highland Creek
# 2      -79.370745      5350016.00                              Moss Park
# 3      -79.410209      5350117.00                              Casa Loma
# 4      -79.365148      5350017.02  St Lawrence-East Bayfront-The Islands
# 5      -79.606184      5350248.04                 West Humber-Clairville
# 6      -79.520169      5350205.00                            New Toronto
# 7      -79.391391      5350036.00                   Kensington-Chinatown
# 8        -79.3496      5350324.03                      Hillcrest Village
# 9        -79.3496      5350324.03                      Hillcrest Village
# 10     -79.500216      5350311.06                York University Heights
# 11     -79.518493      5350316.03                            Black Creek
# 12     -79.399905      5350061.00                             University
# 13     -79.187521      5350362.03                         Highland Creek
# 14     -79.378786      5350034.02                    Downtown Yonge East
# 15     -79.497522      5350311.06                York University Heights
# 16     -79.378038      5350265.00      Bridle Path-Sunnybrook-York Mills
# CPU times: user 2.38 s, sys: 994 µs, total: 2.38 s
# Wall time: 2.43 s

# %% [markdown]
# #### Load

# %% [markdown]
# Export to disk

# %%
# %%time
fname_prefix = "colleges_univs"
_ = df_colleges_univs.pipe(
    flut.load,
    raw_data_dir,
    fname_prefix,
    my_timezone,
    True,
)
# Out:
# Exported 17 rows of colleges_univs data to /home/jovyan/data/raw/systems/toronto/colleges_univs__20240310_172841.parquet.gzip
# CPU times: user 1.94 ms, sys: 0 ns, total: 1.94 ms
# Wall time: 1.74 ms

# %% [markdown]
# ### Daily Weather Data

# %% [markdown]
# #### Extract

# %% [markdown]
# Get weather station ID

# %%
# %%time
station = Stations().nearby(**weather_station_near_coords).fetch(1)
station_id = station.index.get_level_values(0)[0]
# Out:
# CPU times: user 318 ms, sys: 11.8 ms, total: 330 ms
# Wall time: 528 ms

# %% [markdown]
# Run sanity checks to verify correct weather station is returned

# %%
for sub_string in ['Toronto', 'Airport']:
    assert sub_string in station['name'].squeeze()

# %% [markdown]
# Get daily weather data from selected weather station

# %%
# %%time
df_weather = Daily(station_id, weather_start, weather_end).fetch()
# Out:
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# CPU times: user 180 ms, sys: 9.21 ms, total: 189 ms
# Wall time: 1.23 s

# %% [markdown]
# #### Transform

# %% [markdown]
# Append weather station ID to daily weather data

# %%
df_weather = (
    df_weather
    .assign(station_id=station_id)
    .reset_index()
    .convert_dtypes()
)
pu.show_df(df_weather)
# Out:
# column           time    tavg    tmin    tmax    prcp  snow  wdir    wspd  \
# dtype  datetime64[ns] Float64 Float64 Float64 Float64 Int64 Int64 Float64
# nans             0       0       0       0       7     1448  75      9
# 0          2018-01-01   -15.0   -21.3    -8.7     0.0   110  <NA>    19.5
# 1          2018-01-02   -10.5   -13.1    -7.8     1.0   110   241    25.6
# 2          2018-01-03    -9.9   -13.5    -6.3     0.0   100   235    23.2
# 3          2018-01-04   -14.7   -20.5    -8.9     0.0    90   314    27.5
# 4          2018-01-05   -19.0   -23.0   -15.0     0.0    80   311    26.7
# ...               ...     ...     ...     ...     ...   ...   ...     ...
# 1910       2023-03-27     2.9     2.0     5.0     4.9  <NA>    55     9.4
# 1911       2023-03-28     3.5     1.0     6.0     0.1  <NA>   234    10.9
# 1912       2023-03-29     1.5    -3.9     8.0     1.6  <NA>   250    24.6
# 1913       2023-03-30    -1.3    -6.5     4.0     0.0  <NA>   251    14.0
# 1914       2023-03-31     2.4     0.0     4.4     8.3  <NA>   108     9.9
#
# column  wpgt    pres  tsun     station_id
# dtype  Int64 Float64 Int64 string[python]
# nans    721     15    1915           0
# 0       <NA>  1029.1  <NA>          71624
# 1       <NA>  1025.0  <NA>          71624
# 2       <NA>  1017.4  <NA>          71624
# 3       <NA>  1013.8  <NA>          71624
# 4       <NA>  1019.1  <NA>          71624
# ...      ...     ...   ...            ...
# 1910    <NA>  1018.0  <NA>          71624
# 1911    <NA>  1021.9  <NA>          71624
# 1912    <NA>  1018.4  <NA>          71624
# 1913    <NA>  1026.8  <NA>          71624
# 1914    <NA>  1015.0  <NA>          71624
#
# [1915 rows x 12 columns]

# %% [markdown]
# #### Load

# %% [markdown]
# Export to disk

# %%
if not fpaths_weather:
    flut.load(
        df_weather,
        raw_data_dir,
        'daily_weather',
        my_timezone,
        verbose=True,
    )
# Out:
# Exported 1,915 rows of daily_weather data to /home/jovyan/data/raw/systems/toronto/daily_weather__20240310_172843.parquet.gzip

# %% [markdown]
# ### Downtown and East-West Adjacent Neighbourhoods

# %% [markdown]
# #### Extract

# %% [markdown]
# A [large number of Toronto's bike share stations are located in Downtown Toronto](https://bikesharetoronto.com/system-map/). Get neighbourhoods within downtown Toronto and those located immediately to the East and West of Downtown Toronto

# %%
df_downtown_neighs = pd.DataFrame.from_records(neighs)

# %% [markdown]
# #### Transform

# %%
df_downtown_neighs = df_downtown_neighs.convert_dtypes()
pu.show_df(df_downtown_neighs)
# Out:
# column                          Neighbourhood          Location is_downtown
# dtype                          string[python]    string[python]     boolean
# nans                                        0                 0           0
# 0                                  University          Downtown        True
# 1                        Kensington-Chinatown          Downtown        True
# 2                            Wellington Place          Downtown        True
# 3                      Harbourfront-CityPlace          Downtown        True
# 4                              Bay-Cloverhill          Downtown        True
# 5                          Yonge-Bay Corridor          Downtown        True
# 6       St Lawrence-East Bayfront-The Islands          Downtown        True
# 7                            Church-Wellesley          Downtown        True
# 8                         Downtown Yonge East          Downtown        True
# 9                         North St.James Town          Downtown        True
# 10            Cabbagetown-South St.James Town          Downtown        True
# 11                                  Moss Park          Downtown        True
# 12                                Regent Park          Downtown        True
# 13                               Roncesvalles  West of Downtown       False
# 14                             South Parkdale  West of Downtown       False
# 15                             Dufferin Grove  West of Downtown       False
# 16                            Little Portugal  West of Downtown       False
# 17                    Palmerston-Little Italy  West of Downtown       False
# 18                          Trinity-Bellwoods  West of Downtown       False
# 19                            West Queen West  West of Downtown       False
# 20                  Fort York-Liberty Village  West of Downtown       False
# 21                            North Riverdale  East of Downtown       False
# 22                            South Riverdale  East of Downtown       False
# 23                                Blake-Jones  East of Downtown       False

# %% [markdown]
# **Notes**
#
# 1. There are [several definitions of Downtown Toronto](https://www.blogto.com/city/2018/04/downtown-toronto-canada/)'s boundaries. For this project, the boundaries are taken by searching for *Downtown Toronto* on Google Maps.

# %% [markdown]
# #### Load

# %% [markdown]
# Export to disk

# %%
if not fpath_downtown_neighs:
    flut.load(
        df_downtown_neighs,
        raw_data_dir,
        'downtown_neighbourhoods',
        my_timezone,
        verbose=True,
    )
# Out:
# Exported 24 rows of downtown_neighbourhoods data to /home/jovyan/data/raw/systems/toronto/downtown_neighbourhoods__20240310_172843.parquet.gzip

# %% [markdown]
# ### Bike Share Network Expansion Plans

# %% [markdown]
# #### Extract

# %% [markdown]
# Show the planned growth in station footprint that was announced as part of a four-year expansion plan on August 8, 2022 for
#
# 1. stations
#    - [1](https://learn.sharedusemobilitycenter.org/casestudy/bike-share-torontos-four-year-growth-plan-a-data-driven-community-focused-network-expansion/) (**Operations** section)
#    - [2](https://bikesharetoronto.com/news/4-year-growth/)
#    - [3](https://bikesharetoronto.com/news/four-year-growth-plan/) (table 3 in section 3.1 on page 53)
#    - [4](https://www.toronto.ca/wp-content/uploads/2023/06/97f5-2022-Cycling-Year-in-Review-Final.pdf) (page 3)
# 2. bikes
#    - [1](https://bikesharetoronto.com/news/four-year-growth-plan/) (page 7)
#    - [2](https://www.toronto.ca/wp-content/uploads/2023/06/97f5-2022-Cycling-Year-in-Review-Final.pdf) (page 3)
#
# where the listed totals for stations in 1,2 and 3 and for bikes are assumed to correspond to the end of 2022

# %%
df_network_size = pd.DataFrame.from_records(
    [
        {
            'year': 2023,
            'trips': 5_800_000,
            'num_stations': 710+110,
            'num_bikes': 7165+945,
            'frac_neighs_with_bikeshare': None,
        },
        {
            'year': 2024,
            'trips': 7_000_000,
            'num_stations': 710+110+110,
            'num_bikes': 7165+(945*2),
            'frac_neighs_with_bikeshare': None,
        },
        {
            'year': 2025,
            'trips': 8_200_000,
            'num_stations': 710+110+110+115,
            'num_bikes': 7165+(945*3),
            'frac_neighs_with_bikeshare': None,
        },
    ]
)

# %% [markdown]
# **Notes**
#
# 1. Trips totals for future years are as of January 2023 and are based on a rough approximation performed personally and were not taken from published data.

# %% [markdown]
# Convert datatypes

# %%
df_network_size = (
    df_network_size
    .astype({"frac_neighs_with_bikeshare": pd.Float64Dtype()})
    .convert_dtypes()
)
pu.show_df(df_network_size)
# Out:
# column  year    trips num_stations num_bikes frac_neighs_with_bikeshare
# dtype  Int64    Int64        Int64     Int64                    Float64
# nans       0        0            0         0                          3
# 0       2023  5800000          820      8110                       <NA>
# 1       2024  7000000          930      9055                       <NA>
# 2       2025  8200000         1045     10000                       <NA>

# %% [markdown]
# #### Load

# %% [markdown]
# Export to disk

# %%
if not fpath_expansion:
    flut.load(
        df_network_size,
        raw_data_dir,
        'network_expansion',
        my_timezone,
        verbose=True,
    )
# Out:
# Exported 3 rows of network_expansion data to /home/jovyan/data/raw/systems/toronto/network_expansion__20240310_172843.parquet.gzip

# %% [markdown]
# ### Public Transit (Train) Routes in Toronto

# %% [markdown]
# #### Extract and Transform

# %% [markdown]
# Get url of `.zip` file containing `.shp` file with geo data for train transit lines

# %%
# %%time
package = requests.get(url, params=train_line_params).json()
files = package["result"]["resources"]
matching_records = []
for idx, resource in enumerate(files):
    if not resource["datastore_active"]:
        url = base_url + "/api/3/action/resource_show?id=" + resource["id"]
        resource_metadata = requests.get(url).json()
        matching_records.append(resource_metadata)
shp_url = matching_records[0]["result"]["url"]
# Out:
# CPU times: user 44.5 ms, sys: 669 µs, total: 45.1 ms
# Wall time: 359 ms

# %% [markdown]
# Assemble path to local folder where `.zip` file contents will be extracted

# %%
local_fpath = os.path.join(raw_data_dir, os.path.basename(os.path.splitext(shp_url)[0]))

# %% [markdown]
# #### Load

# %% [markdown]
# Download `.zip` file and extract locally, if `.zip` file was not previously downloaded

# %%
if not os.path.exists(local_fpath):
    # Read .zip file containing .shp file for train lines from URL found above
    # (.zip file will be read into memory instead of downloading .zip file to local disk)
    r = requests.get(shp_url)
    myzip = ZipFile(BytesIO(r.content))

    # extract .zip file
    myzip.extractall(local_fpath)
    print(f"Extracted folder containing .shp file to {local_fpath}")
else:
    print(f"Found folder at {local_fpath}. Did nothing.")
# Out:
# Extracted folder containing .shp file to ../data/raw/systems/toronto/ttc-subway-shapefile-wgs84

# %% [markdown]
# Verify that train routes `.shp` file was downloaded and exists locally in the correct filepath

# %%
assert os.path.exists(local_fpath)

# %% [markdown]
# Extract path the `.shp` file with transit lines geodata

# %%
fpath_transit_lines = glob(os.path.join(local_fpath, '*.shp'))[0]

# %% [markdown]
# Show all columns in the transit lines geodata

# %%
# %%time
pu.show_df(gpd.read_file(fpath_transit_lines).convert_dtypes())
# Out:
# column OBJECTID                 ROUTE_NAME   RID  \
# dtype     Int64             string[python] Int64
# nans          0                          0     0
# 0         53420  LINE 1 (YONGE-UNIVERSITY)     1
# 1         53421  LINE 2 (BLOOR - DANFORTH)     2
# 2         53422       LINE 3 (SCARBOROUGH)     3
# 3         53423          LINE 4 (SHEPPARD)     4
#
# column                                           geometry
# dtype                                            geometry
# nans                                                    0
# 0       LINESTRING (-79.52813 43.79677, -79.52689 43.7...
# 1       LINESTRING (-79.53540 43.63781, -79.53386 43.6...
# 2       LINESTRING (-79.26332 43.73266, -79.26332 43.7...
# 3       LINESTRING (-79.41113 43.76145, -79.40981 43.7...
# CPU times: user 18.1 ms, sys: 0 ns, total: 18.1 ms
# Wall time: 17.9 ms

# %% [markdown]
# ### Public Holidays in Canada

# %% [markdown]
# #### Extract

# %%
# %%time
ca_holidays = holidays.CA(
    years=pd.date_range(start=weather_start, end=weather_end, freq='365d').year,
    subdiv='ON',
)
# Out:
# CPU times: user 40.1 ms, sys: 4.02 ms, total: 44.2 ms
# Wall time: 43.7 ms

# %% [markdown]
# #### Transform

# %%
# %%time
df_holidays = (
    pd.DataFrame.from_records(
        [
            {
                "date": datetime.strptime(str(date), '%Y-%m-%d'),
                'holiday_name': holiday_name,
            }
            for date, holiday_name in ca_holidays.items()
        ]
    )
    .assign(is_holiday=True)
    .convert_dtypes()
)
pu.show_df(df_holidays)
# Out:
# column           date                          holiday_name is_holiday
# dtype  datetime64[ns]                        string[python]    boolean
# nans                0                                     0          0
# 0          2018-01-01                        New Year's Day       True
# 1          2018-03-30                           Good Friday       True
# 2          2018-07-01                            Canada Day       True
# 3          2018-09-03                             Labor Day       True
# 4          2018-12-25                         Christmas Day       True
# 5          2018-02-19                            Family Day       True
# 6          2018-05-21                          Victoria Day       True
# 7          2018-10-08                      Thanksgiving Day       True
# 8          2018-12-26                            Boxing Day       True
# 9          2019-01-01                        New Year's Day       True
# 10         2019-04-19                           Good Friday       True
# 11         2019-07-01                            Canada Day       True
# 12         2019-09-02                             Labor Day       True
# 13         2019-12-25                         Christmas Day       True
# 14         2019-02-18                            Family Day       True
# 15         2019-05-20                          Victoria Day       True
# 16         2019-10-14                      Thanksgiving Day       True
# 17         2019-12-26                            Boxing Day       True
# 18         2020-01-01                        New Year's Day       True
# 19         2020-04-10                           Good Friday       True
# 20         2020-07-01                            Canada Day       True
# 21         2020-09-07                             Labor Day       True
# 22         2020-12-25                         Christmas Day       True
# 23         2020-02-17                            Family Day       True
# 24         2020-05-18                          Victoria Day       True
# 25         2020-10-12                      Thanksgiving Day       True
# 26         2020-12-26                            Boxing Day       True
# 27         2021-01-01                        New Year's Day       True
# 28         2021-04-02                           Good Friday       True
# 29         2021-07-01                            Canada Day       True
# 30         2021-09-06                             Labor Day       True
# 31         2021-12-25                         Christmas Day       True
# 32         2021-12-27              Christmas Day (observed)       True
# 33         2021-02-15                            Family Day       True
# 34         2021-05-24                          Victoria Day       True
# 35         2021-10-11                      Thanksgiving Day       True
# 36         2021-12-26                            Boxing Day       True
# 37         2021-12-28                 Boxing Day (observed)       True
# 38         2022-01-01                        New Year's Day       True
# 39         2022-01-03             New Year's Day (observed)       True
# 40         2022-04-15                           Good Friday       True
# 41         2022-07-01                            Canada Day       True
# 42         2022-09-05                             Labor Day       True
# 43         2022-12-25                         Christmas Day       True
# 44         2022-12-26  Boxing Day; Christmas Day (observed)       True
# 45         2022-02-21                            Family Day       True
# 46         2022-05-23                          Victoria Day       True
# 47         2022-10-10                      Thanksgiving Day       True
# CPU times: user 7.34 ms, sys: 0 ns, total: 7.34 ms
# Wall time: 7.1 ms

# %% [markdown]
# #### Load

# %% [markdown]
# Export to disk

# %%
if not fpath_holidays:
    flut.load(
        df_holidays,
        raw_data_dir,
        'holidays',
        my_timezone,
        verbose=True,
    )
# Out:
# Exported 48 rows of holidays data to /home/jovyan/data/raw/systems/toronto/holidays__20240310_172844.parquet.gzip

# %% [markdown]
# ## Discussion

# %% [markdown]
# ### Conclusion
#
# 1. This step has
#    - downloaded data for
#      - Bike Share Toronto ridership from 2018 to 2023, inclusive
#      - City of Toronto Census Tract Boundaries Geodata
#      - City of Toronto Neighbourhood Boundaries Geodata
#      - Bike Share Toronto station info
#      - City of Toronto colleges and universities
#      - City of Toronto Daily Weather Data
#      - City of Toronto Public Transit (Train) Routes Geodata
#    - generated data for
#      - City of Toronto Downtown Neighbourhoods
#      - Bike Share Toronto Network Expandsion Plans (2023 to 2025)

# %% [markdown]
# ## Next Step

# %% [markdown]
# The next step will process the raw bike share trips data that was retrieved during this step.

# %% [markdown]
# ## Version Information

# %%
packages = [
    'requests',
    'meteostat',
    'geopandas',
    'holidays',
    'pandas',
    'pyarrow',
]
print(
    watermark(
        updated=True,
        current_date=True,
        current_time=True,
        timezone=True,
        custom_time="%Y-%m-%d %H:%M:%S %Z",
        python=True,
        machine=True,
        packages=','.join(packages),
    )
)
# Out:
# Last updated: 2024-03-10 21:28:44 UTC
#
# Python implementation: CPython
# Python version       : 3.11.8
# IPython version      : 8.22.2
#
# requests : 2.31.0
# meteostat: 1.6.7
# geopandas: 0.14.3
# holidays : 0.44
# pandas   : 2.2.1
# pyarrow  : 15.0.0
#
# Compiler    : GCC 12.3.0
# OS          : Linux
# Release     : 6.6.10-76060610-generic
# Machine     : x86_64
# Processor   : x86_64
# CPU cores   : 12
# Architecture: 64bit
